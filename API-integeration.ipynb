# %%
import requests


url = "https://imdb236.p.rapidapi.com/imdb/top250-movies"

headers = {
	"x-rapidapi-key": "f6bff73d23msh9d2e7b39773b480p188026jsnd1fe9a60f384",
	"x-rapidapi-host": "imdb236.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

df=response.json()

# %%
import pandas as pd

# %%
df=pd.DataFrame(df)
df
# Out:
#              id                                     url  \
# 0     tt0111161   https://www.imdb.com/title/tt0111161/
# 1     tt0068646   https://www.imdb.com/title/tt0068646/
# 2     tt0468569   https://www.imdb.com/title/tt0468569/
# 3     tt0071562   https://www.imdb.com/title/tt0071562/
# 4     tt0050083   https://www.imdb.com/title/tt0050083/
# ..          ...                                     ...
# 245   tt0107048   https://www.imdb.com/title/tt0107048/
# 246   tt1454029   https://www.imdb.com/title/tt1454029/
# 247   tt0245712   https://www.imdb.com/title/tt0245712/
# 248   tt0032976   https://www.imdb.com/title/tt0032976/
# 249  tt16492678  https://www.imdb.com/title/tt16492678/
#
#                                           primaryTitle  \
# 0                             The Shawshank Redemption
# 1                                        The Godfather
# 2                                      The Dark Knight
# 3                                The Godfather Part II
# ...

# %%
df=df[['id','url']]

# %%
df
# Out:
#              id                                     url
# 0     tt0111161   https://www.imdb.com/title/tt0111161/
# 1     tt0068646   https://www.imdb.com/title/tt0068646/
# 2     tt0468569   https://www.imdb.com/title/tt0468569/
# 3     tt0071562   https://www.imdb.com/title/tt0071562/
# 4     tt0050083   https://www.imdb.com/title/tt0050083/
# ..          ...                                     ...
# 245   tt0107048   https://www.imdb.com/title/tt0107048/
# 246   tt1454029   https://www.imdb.com/title/tt1454029/
# 247   tt0245712   https://www.imdb.com/title/tt0245712/
# 248   tt0032976   https://www.imdb.com/title/tt0032976/
# 249  tt16492678  https://www.imdb.com/title/tt16492678/
#
# [250 rows x 2 columns]
