# %%
import pandas as pd

# %%
a=[1,2,3,4,4]
pd.Series(a)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    4
# dtype: int64

# %%
b=[1,2,3,4,'f']
pd.Series(b)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    f
# dtype: object

# %%
a={'as':'s','b':4,3:33,'&':'*'}
b=pd.Series(a)
b
# Out:
# as     s
# b      4
# 3     33
# &      *
# dtype: object

# %%
import numpy as np
a=np.array([2,3,4,'6'])
b=pd.Series(a)
b
# Out:
# 0    2
# 1    3
# 2    4
# 3    6
# dtype: object

# %%
data=[['a',3],['d',4],['df',5],['f',3],[2,3],['df','5']]
data
# Out:
# [['a', 3], ['d', 4], ['df', 5], ['f', 3], [2, 3], ['df', '5']]

# %%
import numpy as np
o=np.array(data)
o
# Out:
# array([['a', '3'],
#        ['d', '4'],
#        ['df', '5'],
#        ['f', '3'],
#        ['2', '3'],
#        ['df', '5']], dtype='<U11')

# %%
np.size(data)
# Out:
# 12

# %%
np.ndim(data)
# Out:
# 2

# %%
np.shape(data)
# Out:
# (6, 2)

# %%
pd.DataFrame(data)
# Out:
#     0  1
# 0   a  3
# 1   d  4
# 2  df  5
# 3   f  3
# 4   2  3
# 5  df  5

# %%
pd.DataFrame(data,columns=['name','age'])
# Out:
#   name age
# 0    a   3
# 1    d   4
# 2   df   5
# 3    f   3
# 4    2   3
# 5   df   5

# %%
d=pd.DataFrame(data,index=range(11,17))
# d=pd.DataFrame(data,index=range(121,127))
d
# Out:
#    name  age
# 11    a    3
# 12    d    4
# 13   df    5
# 14    f    3
# 15    2    3
# 16   df    5

# %%
d.columns=['name','age',]
d
# Out:
#    name  age
# 11    a    3
# 12    d    4
# 13   df    5
# 14    f    3
# 15    2    3
# 16   df    5

# %%
# np.array(d).add(['as',3],['df',32])
# d=np.array([['as',4],['ssf',3]])
# d
# d
# d=np.append(d,['as',3])

new_data = {"name": "new_name", "age": 30}  
d = np.append(new_data, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[221], line 8
#       1 # np.array(d).add(['as',3],['df',32])
#       2 # d=np.array([['as',4],['ssf',3]])
#       3 # d
#       4 # d
#       5 # d=np.append(d,['as',3])
#       7 new_data = {"name": "new_name", "age": 30}
# ----> 8 d = np.append(new_data, ignore_index=True)
#
# TypeError: append() got an unexpected keyword argument 'ignore_index'

# %%
d=pd.DataFrame(d)
d
# Out:
#    name  age
# 11    a    3
# 12    d    4
# 13   df    5
# 14    f    3
# 15    2    3
# 16   df    5

# %%
import pandas as pd
import numpy as np

# Existing NumPy array
d = np.array([["a", 3], ["d", 4], ["df", 5], ["f", 3], ["2", 3], ["df", 5]])

# New data to append
new_data = np.array(["new_name", 30])

# Append new data (ensure the same shape)
d = pd.Series([d, new_data])  # Vertically stack arrays
print(d)
# Out:
# 0    [[a, 3], [d, 4], [df, 5], [f, 3], [2, 3], [df,...
# 1                                       [new_name, 30]
# dtype: object

# %%
a=pd.Series(d)
a
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[235], line 1
# ----> 1 a=pd.Series(d)
#       2 a
#
# File E:\newanaconda\Lib\site-packages\pandas\core\series.py:584, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     582         data = data.copy()
#     583 else:
# --> 584     data = sanitize_array(data, index, dtype, copy)
#     586     manager = _get_option("mode.data_manager", silent=True)
#     587     if manager == "block":
#
# File E:\newanaconda\Lib\site-packages\pandas\core\construction.py:659, in sanitize_array(data, index, dtype, copy, allow_2d)
#     656             subarr = cast(np.ndarray, subarr)
#     657             subarr = maybe_infer_to_datetimelike(subarr)
# --> 659 subarr = _sanitize_ndim(subarr, data, dtype, index, allow_2d=allow_2d)
#     661 if isinstance(subarr, np.ndarray):
# ...

# %%
d
# Out:
#    name  real age
# 11    a         3
# 12    d         4
# 13   df         5
# 14    f         3
# 15    2         3
# 16   df         5

# %%
a=d.rename({'age':'real age'})
d
# Out:
#    name  real age
# 11    a         3
# 12    d         4
# 13   df         5
# 14    f         3
# 15    2         3
# 16   df         5

# %%
d.to_csv('new.csv')

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is EEA1-095D
#
#  Directory of C:\Users\akhil\juypter_notebook
#
# 02-04-2025  22:16    <DIR>          .
# 02-04-2025  09:46    <DIR>          ..
# 02-04-2025  22:16    <DIR>          .ipynb_checkpoints
# 02-04-2025  22:14                66 new.csv
# 01-04-2025  10:13            11,521 Pandas assignment.docx
# 02-04-2025  22:16            26,975 pandas.ipynb
# 01-04-2025  10:13            61,194 train.csv
# 01-04-2025  09:36            20,896 Untitled.ipynb
#                5 File(s)        120,652 bytes
#                3 Dir(s)  340,010,287,104 bytes free

# %%
data=pd.read_csv('train.csv')

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
a=data['Fare'].unique
a
# when i am using () in front of unique output is differnet and when not applying than output is different
# Out:
# <bound method Series.unique of 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 891, dtype: float64>

# %%
len(data['Fare'].unique())
# Out:
# 248

# %%
data['Cabin']
# Out:
# 0       NaN
# 1       C85
# 2       NaN
# 3      C123
# 4       NaN
#        ...
# 886     NaN
# 887     B42
# 888     NaN
# 889    C148
# 890     NaN
# Name: Cabin, Length: 891, dtype: object

# %%
a=data.loc[data['Sex']=='male']. reset_index(drop=True)
a
# a = data.loc[data['Sex'] == 'male'].reset_index(drop=True)  # ✅ Correct with new index
# a
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 1              5         0       3        Allen, Mr. William Henry  male
# 2              6         0       3                Moran, Mr. James  male
# 3              7         0       1         McCarthy, Mr. Timothy J  male
# 4              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 572          884         0       2   Banfield, Mr. Frederick James  male
# 573          885         0       3          Sutehall, Mr. Henry Jr  male
# 574          887         0       2           Montvila, Rev. Juozas  male
# 575          890         1       1           Behr, Mr. Karl Howell  male
# 576          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
len(a==True)
# Out:
# 891

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.loc[data['Sex']=='male']
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
data.loc[(data['Sex']=='female') & (data['Survived']==0)]
# Out:
#      PassengerId  Survived  Pclass  \
# 14            15         0       3
# 18            19         0       3
# 24            25         0       3
# 38            39         0       3
# 40            41         0       3
# ..           ...       ...     ...
# 854          855         0       2
# 863          864         0       3
# 882          883         0       3
# 885          886         0       3
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 14                Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 24                       Palsson, Miss. Torborg Danira  female   8.0      3
# 38                  Vander Planke, Miss. Augusta Maria  female  18.0      2
# 40      Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female  40.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
len(aa)
# Out:
# 314

# %%
np.where(data['Age']==1)
# Out:
# (array([164, 172, 183, 381, 386, 788, 827], dtype=int64),)

# %%
np.where(data['Fare']==18)
# Out:
# (array([ 18,  38, 333], dtype=int64),)

# %%
data.iloc[(np.where(data['Age']==80))]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
#
#       Sex   Age  SibSp  Parch Ticket  Fare Cabin Embarked
# 630  male  80.0      0      0  27042  30.0   A23        S

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
aa=data['Age'].isnull().sum()
aa
# Out:
# 177

# %%
len(data[data['Age'].isnull()])
# len(data[data['Age'].isnull()])  # ✅ Alternative method
# Out:
# 177

# %%
data.Sex.value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
pd.set_option('display.max_rows',None)

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
pd.reset_option('display.max_rows',None)

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
pd.reset_option('display.max_rows')
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data=pd.set_option('display.max_columns',None)

# %%
a

# %%
data[['Age','Survived','Ticket']]
# Out:
#       Age  Survived            Ticket
# 0    22.0         0         A/5 21171
# 1    38.0         1          PC 17599
# 2    26.0         1  STON/O2. 3101282
# 3    35.0         1            113803
# 4    35.0         0            373450
# ..    ...       ...               ...
# 886  27.0         0            211536
# 887  19.0         1            112053
# 888   NaN         0        W./C. 6607
# 889  26.0         1            111369
# 890  32.0         0            370376
#
# [891 rows x 3 columns]

# %%
data.loc[34:55,['Age','Ticket']]
# Out:
#      Age           Ticket
# 34  28.0         PC 17604
# 35  42.0           113789
# 36   NaN             2677
# 37  21.0       A./5. 2152
# 38  18.0           345764
# 39  14.0             2651
# 40  40.0             7546
# 41  27.0            11668
# 42   NaN           349253
# 43   3.0    SC/Paris 2123
# 44  19.0           330958
# 45   NaN  S.C./A.4. 23567
# 46   NaN           370371
# 47   NaN            14311
# 48   NaN             2662
# 49  18.0           349237
# 50   7.0          3101295
# 51  21.0       A/4. 39886
# 52  49.0         PC 17572
# 53  29.0             2926
# 54  65.0           113509
# 55   NaN            19947

# %%
data['Age']=data.Age.astype('float32')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float32
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float32(1), float64(1), int64(5), object(5)
# memory usage: 80.2+ KB

# %%
data['Fare']=pd.to_numeric(data.Fare,downcast='float')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float32
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float32
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float32(2), int64(5), object(5)
# memory usage: 76.7+ KB
