# %%
import pandas as pd

# %%
x=[1,2,3,4,5,6]
pd.Series(x,index=['a','b','c','d','e','3'],dtype='float',name='pd')
# Out:
# a    1.0
# b    2.0
# c    3.0
# d    4.0
# e    5.0
# 3    6.0
# Name: pd, dtype: float64

# %%
dic={'a':'dsf','b':['asd',9,'',['#',{'a':0}]],'da':('adf',9,'9o'),'f':4,2:4}
tup=(1,2,'d','g')
pd.Series(tup)
# Out:
# 0    1
# 1    2
# 2    d
# 3    g
# dtype: object

# %%
s1=pd.Series([[12,34]])
s2=pd.Series([[13],[3]])
s1+s2
# Out:
# 0    [12, 34, 13]
# 1             NaN
# dtype: object

# %%
dicc={'1':['2','9'],'3':['3','l'],'o':['k','l'],'l':("0",'l')}
pd.DataFrame(dicc)
# Out:
#    1  3  o  l
# 0  2  3  k  0
# 1  9  l  l  l

# %%
var=pd.DataFrame({'A':[1,2,3,4,5],'B':[6,7,8,9,12]})
var
# Out:
#    A   B
# 0  1   6
# 1  2   7
# 2  3   8
# 3  4   9
# 4  5  12

# %%
var['sum']=var['A']/var['B']
var
# Out:
#    A   B       sum
# 0  1   6  0.166667
# 1  2   7  0.285714
# 2  3   8  0.375000
# 3  4   9  0.444444
# 4  5  12  0.416667

# %%
var['t','ll']=(var['A']>3)&(var['B']>8)
var
# Out:
#    A   B       sum  (t, ll)
# 0  1   6  0.166667    False
# 1  2   7  0.285714    False
# 2  3   8  0.375000    False
# 3  4   9  0.444444     True
# 4  5  12  0.416667     True

# %%
# var[ins]=var[0,['A']
var.insert(2,'akc',[5,7,89,6,9])
var
# Out:
#    A   B  akc       sum  (t, ll)
# 0  1   6    5  0.166667    False
# 1  2   7    7  0.285714    False
# 2  3   8   89  0.375000    False
# 3  4   9    6  0.444444     True
# 4  5  12    9  0.416667     True

# %%
# var=pd.DataFrame({'A':[1,2,3,4,5],'B':[6,7,8,9,12]})
var['pd']=var['A'][:3]
var
# Out:
#    A   B  akc       sum  (t, ll)   pd
# 0  1   6    5  0.166667    False  1.0
# 1  2   7    7  0.285714    False  2.0
# 2  3   8   89  0.375000    False  3.0
# 3  4   9    6  0.444444     True  NaN
# 4  5  12    9  0.416667     True  NaN

# %%
var.pop('pd')
var
# Out:
#    A   B  akc       sum  (t, ll)
# 0  1   6    5  0.166667    False
# 1  2   7    7  0.285714    False
# 2  3   8   89  0.375000    False
# 3  4   9    6  0.444444     True
# 4  5  12    9  0.416667     True

# %%
var.to_csv('test2.csv',index=False,header=[7,9,9,8,9],dtype={'float'})
var
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[346], line 1
# ----> 1 var.to_csv('test2.csv',index=False,header=[7,9,9,8,9],dtype={'float'})
#       2 var
#
# File E:\newanaconda\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# TypeError: NDFrame.to_csv() got an unexpected keyword argument 'dtype'

# %%
t=pd.read_csv('train.csv')

# %%
t.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
t.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
t.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
t.sort_values(by='Age',axis=0,ascending=False)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 630          631         1       1      Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                       Svensson, Mr. Johan
# 493          494         0       1                   Artagaveytia, Mr. Ramon
# 96            97         0       1                 Goldschmidt, Mr. George B
# 116          117         0       3                      Connors, Mr. Patrick
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
a=t.dropna()
a
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
a.sort_values(by='Age',axis=0,ascending=False)
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 96            97         0       1             Goldschmidt, Mr. George B
# 745          746         0       1          Crosby, Capt. Edward Gifford
# 456          457         0       1             Millet, Mr. Francis Davis
# 54            55         0       1        Ostby, Mr. Engelhart Cornelius
# ..           ...       ...     ...                                   ...
# 297          298         0       1          Allison, Miss. Helen Loraine
# 205          206         0       3            Strom, Miss. Telma Matilda
# 340          341         1       2        Navratil, Master. Edmond Roger
# 183          184         1       2             Becker, Master. Richard F
# 305          306         1       1        Allison, Master. Hudson Trevor
#
#         Sex    Age  SibSp  Parch     Ticket      Fare    Cabin Embarked
# ...

# %%
var1=pd.DataFrame({'A':[1,2,3,4,5],'B':[11,22,33,444,55]})
var2=pd.DataFrame({'A':[1,2,3,4,5],'C':[101,202,303,404,505]})

pd.merge(var1,var2)
# Out:
#    A    B    C
# 0  1   11  101
# 1  2   22  202
# 2  3   33  303
# 3  4  444  404
# 4  5   55  505
